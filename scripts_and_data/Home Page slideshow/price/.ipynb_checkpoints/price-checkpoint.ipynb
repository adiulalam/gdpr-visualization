# %%
from bokeh.plotting import figure, output_file, show, save, ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Blues8
from bokeh.embed import components
import pandas
import pandas as pd

# %%
df = pandas.read_csv('price.csv')

# Create ColumnDataSource from data frame
source = ColumnDataSource(df)

output_file('price.html')

# %%
# Device list
Device_list = source.data['Device'].tolist()


# Add plot
p = figure(
    y_range=Device_list,
    plot_width=950,
    plot_height=500,
    title='Price Per Smart Device',
    x_axis_label='Price (£)',
    tools="pan,box_select,zoom_in,zoom_out,save,reset"
)

# Render glyph
p.hbar(
    y='Device',
    right='Price',
    left=0,
    height=0.4,
    fill_color=factor_cmap(
      'Device',
      palette=Blues8,
      factors=Device_list
    ),
    fill_alpha=0.9,
    source=source,
    legend_label='Smart Devices'
)

# Add Legend
p.legend.orientation = 'vertical'
p.legend.location = 'top_right'
p.legend.label_text_font_size = '10px'

# Add Tooltips
hover = HoverTool()
hover.tooltips = """
  <div>
    <h3>@Device</h3>
    <div><strong>Brand: </strong>@Brand</div>
    <div><strong>Price: £</strong>@Price</div>
    <div><img src="@Image" alt="" width="100" /></div>
  </div>
"""
p.add_tools(hover)

# Show results
show(p)

# Save file
save(p)

# Print out div and script
script, div = components(p)
print(div)
print(script)
# Out:
# <div class="bk-root" id="50230651-bd98-4e0a-bd00-800132566309" data-root-id="1233"></div>
#
# <script type="text/javascript">
#     (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
#               (function(root) {
#                 function embed_document(root) {
#
#                 var docs_json = '{"c6a086d0-632e-4eb9-8b9f-b51d3527f974":{"roots":{"references":[{"attributes":{"label":{"value":"Smart Devices"},"renderers":[{"id":"1269"}]},"id":"1280","type":"LegendItem"},{"attributes":{"callback":null,"tooltips":"\\n  &lt;div&gt;\\n    &lt;h3&gt;@Device&lt;/h3&gt;\\n    &lt;div&gt;&lt;strong&gt;Brand: &lt;/strong&gt;@Brand&lt;/div&gt;\\n    &lt;div&gt;&lt;strong&gt;Price: \\u00a3&lt;/strong&gt;@Price&lt;/div&gt;\\n    &lt;div&gt;&lt;img src=\\"@Image\\" alt=\\"\\" width=\\"100\\" /&gt;&lt;/div&gt;\\n  &lt;/div&gt;\\n"},"id":"1281","type":"HoverTool"},{"attributes":{"bottom_units":"screen","fill_alpha":0.5,"fill_color":"lightgrey","left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","top_units":"screen"},"id":"1257","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"1275"},"ticker":{"id":"1249"}},"id":"1248","type":"CategoricalAxis"},{"attributes":{},"id":"1275","type":"CategoricalTickFormatter"},{"attributes":{"below":[{"id":"1244"}],"center":[{"id":"1247"},{"id":"1250"},{"id":"1279"}],"left":[{"id":"1248"}],"plot_height":500,"plot_width":950,"renderers":[{"id":"1269"}],"title":{"id":"1234"},"toolbar":{"id":"1258"},"x_range":{"id":"1236"},"x_scale":{"id":"1240"},"y_range":{"id":"1238"},"y_scale":{"id":"1242"}},"id":"1233","subtype":"Figure","type":"Plot"},{"attributes":{"axis":{"id":"1248"},"dimension":1,"ticker":null},"id":"1250","type":"Grid"},{"attributes":{},"id":"1253","type":"ZoomInTool"},{"attributes":{"items":[{"id":"1280"}],"label_text_font_size":"10px"},"id":"1279","type":"Legend"},{"attributes":{},"id":"1249","type":"CategoricalTicker"},{"attributes":{},"id":"1273","type":"BasicTickFormatter"},{"attributes":{},"id":"1254","type":"ZoomOutTool"},{"attributes":{},"id":"1242","type":"CategoricalScale"},{"attributes":{},"id":"1236","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"field":"Device","transform":{"id":"1265"}},"height":{"value":0.4},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"Price"},"y":{"field":"Device"}},"id":"1268","type":"HBar"},{"attributes":{},"id":"1251","type":"PanTool"},{"attributes":{},"id":"1255","type":"SaveTool"},{"attributes":{},"id":"1276","type":"UnionRenderers"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1251"},{"id":"1252"},{"id":"1253"},{"id":"1254"},{"id":"1255"},{"id":"1256"},{"id":"1281"}]},"id":"1258","type":"Toolbar"},{"attributes":{},"id":"1277","type":"Selection"},{"attributes":{"factors":["Philips Hue White Smart Bulb","Fire TV Stick 4K","Amazon Echo Dot","TP-Link Kasa Smart Camera","Google Home Mini"],"palette":["#084594","#2171b5","#4292c6","#6baed6","#9ecae1","#c6dbef","#deebf7","#f7fbff"]},"id":"1265","type":"CategoricalColorMapper"},{"attributes":{"factors":["Philips Hue White Smart Bulb","Fire TV Stick 4K","Amazon Echo Dot","TP-Link Kasa Smart Camera","Google Home Mini"]},"id":"1238","type":"FactorRange"},{"attributes":{"axis":{"id":"1244"},"ticker":null},"id":"1247","type":"Grid"},{"attributes":{"overlay":{"id":"1257"}},"id":"1252","type":"BoxSelectTool"},{"attributes":{},"id":"1245","type":"BasicTicker"},{"attributes":{"data_source":{"id":"1232"},"glyph":{"id":"1267"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1268"},"selection_glyph":null,"view":{"id":"1270"}},"id":"1269","type":"GlyphRenderer"},{"attributes":{"data":{"Brand":["Philips","Amazon","Amazon","TP-Link","Google"],"Device":["Philips Hue White Smart Bulb","Fire TV Stick 4K","Amazon Echo Dot","TP-Link Kasa Smart Camera","Google Home Mini"],"Image":["https://m.media-amazon.com/images/I/516MZxTzpIS._AC_SL1001_.jpg","https://images-na.ssl-images-amazon.com/images/I/51ea0oGhZUL._AC_SX569_.jpg","https://images-na.ssl-images-amazon.com/images/I/61u48FEs0rL._AC_SX679_.jpg","https://images-na.ssl-images-amazon.com/image ...
#                 var render_items = [{"docid":"c6a086d0-632e-4eb9-8b9f-b51d3527f974","root_ids":["1233"],"roots":{"1233":"50230651-bd98-4e0a-bd00-800132566309"}}];
#                 root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                 }
#                 if (root.Bokeh !== undefined) {
#                   embed_document(root);
#                 } else {
#                   var attempts = 0;
#                   var timer = setInterval(function(root) {
#                     if (root.Bokeh !== undefined) {
#                       clearInterval(timer);
#                       embed_document(root);
#                     } else {
#                       attempts++;
#                       if (attempts > 100) {
#                         clearInterval(timer);
#                         console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                       }
#                     }
#                   }, 10, root)
#                 }
#               })(window);
#             });
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
# </script>
